# %%
from utils_obsidian import remove_yaml_field_from_md

# %% [markdown]
# Ce script ajoute un champ yaml & une valeur à tous les fichiers .md contenus dans un repertoire

# %%
# -----------------------------
# 🔧 VARIABLES À MODIFIER
# -----------------------------
DIRECTORY = r"C:\Users\virgil.mesle\OneDrive - Sirius Space Services\Documents\obsidian_pro\companies"
FIELD = "offers" 
RECURSIVE = False   # mettre False pour non-récursif
# -----------------------------

# %%
if __name__ == "__main__":
    # Exemple d'utilisation
    remove_yaml_field_from_md(
        directory=DIRECTORY,
        field_name=FIELD,
        recursive=RECURSIVE
    )
# Out:
# 🗑️ Champ 'offers' supprimé dans C:\Users\virgil.mesle\OneDrive - Sirius Space Services\Documents\obsidian_pro\companies\Aerospacelab.md
# 🗑️ Champ 'offers' supprimé dans C:\Users\virgil.mesle\OneDrive - Sirius Space Services\Documents\obsidian_pro\companies\Agena Space.md
# 🗑️ Champ 'offers' supprimé dans C:\Users\virgil.mesle\OneDrive - Sirius Space Services\Documents\obsidian_pro\companies\Alpha Impulsion.md
# 🗑️ Champ 'offers' supprimé dans C:\Users\virgil.mesle\OneDrive - Sirius Space Services\Documents\obsidian_pro\companies\Axiom Space.md
# 🗑️ Champ 'offers' supprimé dans C:\Users\virgil.mesle\OneDrive - Sirius Space Services\Documents\obsidian_pro\companies\ClearSpace.md
# 🗑️ Champ 'offers' supprimé dans C:\Users\virgil.mesle\OneDrive - Sirius Space Services\Documents\obsidian_pro\companies\Comat.md
# 🗑️ Champ 'offers' supprimé dans C:\Users\virgil.mesle\OneDrive - Sirius Space Services\Documents\obsidian_pro\companies\EnduroSat.md
# 🗑️ Champ 'offers' supprimé dans C:\Users\virgil.mesle\OneDrive - Sirius Space Services\Documents\obsidian_pro\companies\Expleo.md
# 🗑️ Champ 'offers' supprimé dans C:\Users\virgil.mesle\OneDrive - Sirius Space Services\Documents\obsidian_pro\companies\Gama Space.md
# 🗑️ Champ 'offers' supprimé dans C:\Users\virgil.mesle\OneDrive - Sirius Space Services\Documents\obsidian_pro\companies\Gomspace.md
# 🗑️ Champ 'offers' supprimé dans C:\Users\virgil.mesle\OneDrive - Sirius Space Services\Documents\obsidian_pro\companies\Hemeria.md
# 🗑️ Champ 'offers' supprimé dans C:\Users\virgil.mesle\OneDrive - Sirius Space Services\Documents\obsidian_pro\companies\Hstar.md
# 🗑️ Champ 'offers' supprimé dans C:\Users\virgil.mesle\OneDrive - Sirius Space Services\Documents\obsidian_pro\companies\HyPrSpace.md
# 🗑️ Champ 'offers' supprimé dans C:\Users\virgil.mesle\OneDrive - Sirius Space Services\Documents\obsidian_pro\companies\Infinite Orbits.md
# 🗑️ Champ 'offers' supprimé dans C:\Users\virgil.mesle\OneDrive - Sirius Space Services\Documents\obsidian_pro\companies\IRAP.md
# 🗑️ Champ 'offers' supprimé dans C:\Users\virgil.mesle\OneDrive - Sirius Space Services\Documents\obsidian_pro\companies\Isar Aerospace.md
# 🗑️ Champ 'offers' supprimé dans C:\Users\virgil.mesle\OneDrive - Sirius Space Services\Documents\obsidian_pro\companies\Kinéis.md
# 🗑️ Champ 'offers' supprimé dans C:\Users\virgil.mesle\OneDrive - Sirius Space Services\Documents\obsidian_pro\companies\LAM.md
# 🗑️ Champ 'offers' supprimé dans C:\Users\virgil.mesle\OneDrive - Sirius Space Services\Documents\obsidian_pro\companies\Lattitude.md
# 🗑️ Champ 'offers' supprimé dans C:\Users\virgil.mesle\OneDrive - Sirius Space Services\Documents\obsidian_pro\companies\NanoXplore.md
# 🗑️ Champ 'offers' supprimé dans C:\Users\virgil.mesle\OneDrive - Sirius Space Services\Documents\obsidian_pro\companies\NovaSpace.md
# 🗑️ Champ 'offers' supprimé dans C:\Users\virgil.mesle\OneDrive - Sirius Space Services\Documents\obsidian_pro\companies\OHB.md
# 🗑️ Champ 'offers' supprimé dans C:\Users\virgil.mesle\OneDrive - Sirius Space Services\Documents\obsidian_pro\companies\Orbex.md
# 🗑️ Champ 'offers' supprimé dans C:\Users\virgil.mesle\OneDrive - Sirius Space Services\Documents\obsidian_pro\companies\Orbital Views.md
# 🗑️ Champ 'offers' supprimé dans C:\Users\virgil.mesle\OneDrive - Sirius Space Services\Documents\obsidian_pro\companies\PLD space.md
# 🗑️ Champ 'offers' supprimé dans C:\Users\virgil.mesle\OneDrive - Sirius Space Services\Documents\obsidian_pro\companies\RFA.md
# 🗑️ Champ 'offers' supprimé dans C:\Users\virgil.mesle\OneDrive - Sirius Space Services\Documents\obsidian_pro\companies\Rovial Space.md
# 🗑️ Champ 'offers' supprimé dans C:\Users\virgil.mesle\OneDrive - Sirius Space Services\Documents\obsidian_pro\companies\Safran.md
# 🗑️ Champ 'offers' supprimé dans C:\Users\virgil.mesle\OneDrive - Sirius Space Services\Documents\obsidian_pro\companies\SAS - Space Application Services.md
# 🗑️ Champ 'offers' supprimé dans C:\Users\virgil.mesle\OneDrive - Sirius Space Services\Documents\obsidian_pro\companies\Telespazio.md
# 🗑️ Champ 'offers' supprimé dans C:\Users\virgil.mesle\OneDrive - Sirius Space Services\Documents\obsidian_pro\companies\Thales.md
# 🗑️ Champ 'offers' supprimé dans C:\Users\virgil.mesle\OneDrive - Sirius Space Services\Documents\obsidian_pro\companies\The Exploration Company.md
# 🗑️ Champ 'offers' supprimé dans C:\Users\virgil.mesle\OneDrive - Sirius Space Services\Documents\obsidian_pro\companies\U Space.md
# 🗑️ Champ 'offers' supprimé dans C:\Users\virgil.mesle\OneDrive - Sirius Space Services\Documents\obsidian_pro\companies\Unseenlabs.md
# 🗑️ Champ 'offers' supprimé dans C:\Users\virgil.mesle\OneDrive - Sirius Space Services\Documents\obsidian_pro\companies\Venturi Space.md
# 🗑️ Champ 'offers' supprimé dans C:\Users\virgil.mesle\OneDrive - Sirius Space Services\Documents\obsidian_pro\companies\VeoWare Space.md
