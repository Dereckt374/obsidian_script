# %%
from utils_obsidian import remove_yaml_field_from_md

# %% [markdown]
# Ce script ajoute un champ yaml & une valeur à tous les fichiers .md contenus dans un repertoire

# %%
# -----------------------------
# 🔧 VARIABLES À MODIFIER
# -----------------------------
DIRECTORY =r"C:\Users\virgil.mesle\Documents\architecture-systeme\2.Functional\Functions"
FIELD = "name"  # nom du champ YAML à supprimer
RECURSIVE = False   # mettre False pour non-récursif
# -----------------------------

# %%
if __name__ == "__main__":
    # Exemple d'utilisation
    remove_yaml_field_from_md(
        directory=DIRECTORY,
        field_name=FIELD,
        recursive=RECURSIVE
    )
# Out:
# 🗑️ Champ 'name' supprimé dans C:\Users\virgil.mesle\Documents\architecture-systeme\2.Functional\Functions\F1 - Integrate, prepare and protect launcher for launch mission.md
# 🗑️ Champ 'name' supprimé dans C:\Users\virgil.mesle\Documents\architecture-systeme\2.Functional\Functions\F1.1 - Prepare and test launcher by means of ground.md
# 🗑️ Champ 'name' supprimé dans C:\Users\virgil.mesle\Documents\architecture-systeme\2.Functional\Functions\F1.1.1 - Enable ground-based control, communication, power, and monitoring.md
# 🗑️ Champ 'name' supprimé dans C:\Users\virgil.mesle\Documents\architecture-systeme\2.Functional\Functions\F1.1.1.1 - Send data to Launch Base.md
# 🗑️ Champ 'name' supprimé dans C:\Users\virgil.mesle\Documents\architecture-systeme\2.Functional\Functions\F1.1.1.2 - Receive commands from Launch Base.md
# 🗑️ Champ 'name' supprimé dans C:\Users\virgil.mesle\Documents\architecture-systeme\2.Functional\Functions\F1.1.1.3 - Receive power from the Launch Base.md
# ...
