# %%
from utils_obsidian import move_md_by_yaml_header

# %%
OBS_REPO = r"C:\Users\virgil.mesle\OneDrive - Sirius Space Services\Documents\LOS\obsidian_los"

# %%
# Exemple d'utilisation :
move_md_by_yaml_header(
    root_dir=OBS_REPO,
    yaml_key="type",
    yaml_value="Spec",
    dest_dir=r"C:\Users\virgil.mesle\OneDrive - Sirius Space Services\Documents\LOS\obsidian_los\Specs"
)
move_md_by_yaml_header(
    root_dir=OBS_REPO,
    yaml_key="type",
    yaml_value='Document',
    dest_dir=r"C:\Users\virgil.mesle\OneDrive - Sirius Space Services\Documents\LOS\obsidian_los\Documents"
)
# Out:
# Déplacement : C:\Users\virgil.mesle\OneDrive - Sirius Space Services\Documents\LOS\obsidian_los\Documents\ST-RT-16.3.3.md → C:\Users\virgil.mesle\OneDrive - Sirius Space Services\Documents\LOS\obsidian_los\Specs\ST-RT-16.3.3.md
# Déplacement : C:\Users\virgil.mesle\OneDrive - Sirius Space Services\Documents\LOS\obsidian_los\Documents\ST-RT-16.3.4.md → C:\Users\virgil.mesle\OneDrive - Sirius Space Services\Documents\LOS\obsidian_los\Specs\ST-RT-16.3.4.md
# Déplacement : C:\Users\virgil.mesle\OneDrive - Sirius Space Services\Documents\LOS\obsidian_los\Documents\ST-RT-16.3.5.md → C:\Users\virgil.mesle\OneDrive - Sirius Space Services\Documents\LOS\obsidian_los\Specs\ST-RT-16.3.5.md
# Déplacement : C:\Users\virgil.mesle\OneDrive - Sirius Space Services\Documents\LOS\obsidian_los\Documents\ST-RT-16.3.6.md → C:\Users\virgil.mesle\OneDrive - Sirius Space Services\Documents\LOS\obsidian_los\Specs\ST-RT-16.3.6.md
# ...
